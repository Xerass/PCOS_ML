# %% [markdown]
# Imports for the program to work, no need to include in the methods as this is secondary.

# %%
import pandas as pd
import numpy as np
import torch
import re
from pathlib import Path
from typing import Tuple, Dict, Any

from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report

# %% [markdown]
# Config for model training, again, safe to ignore for your method needs

# %%
XLSX_PATH = "PCOS_data_without_infertility.xlsx"   # or the full path if needed
SHEET_NAME = "Full_new"                            # your data sheet
TARGET_COL = "PCOS (Y/N)"                          # label column

# columns that are clearly not useful as features
DROP_COLS = [
    "Sl. No", 
    "Patient File No.",
    "Unnamed: 44", 
    "Pulse rate(bpm)", 
    "RR (breaths/min)", 
    "Hb(g/dl)","BP _Systolic (mmHg)",
    "BP _Diastolic (mmHg)",
    "Pimples(Y/N)",
    "Blood Group", 
    "Skin darkening (Y/N)",
    "No. of abortions",
    "Fast food (Y/N)", "Reg.Exercise(Y/N)",
    "Marraige Status (Yrs)",
    "Vit D3 (ng/mL)",
    "Pregnant(Y/N)",
]

# %% [markdown]
# Helper functions, not needed in methods as its for easier implementation of training later

# %%
# blood Group mapping as specified by the excel sheet
BLOOD_GROUP_MAP = {
    "A+": 11, "A-": 12, "B+": 13, "B-": 14, "O+": 15, "O-": 16, "AB+": 17, "AB-": 18,
}

def normalize_yes_no(series: pd.Series) -> pd.Series:
    """Convert Yes/No variants to {1,0}; keep NaN for blanks."""
    def to01(v):
        if pd.isna(v): 
            return np.nan
        s = str(v).strip().lower()
        if s in {"yes", "y", "1", "true"}:  return 1
        if s in {"no", "n", "0", "false"}:  return 0
        # tolerate numbers given as strings
        try:
            f = float(s)
            if f in (0.0, 1.0): 
                return int(f)
        except:
            pass
        return np.nan
    return series.map(to01)

def choose_splits(n_rows: int) -> Tuple[float, float, float]:
    """Return (train, val, test) fractions based on dataset size."""
    if n_rows < 1000:
        return 0.70, 0.15, 0.15
    elif n_rows < 5000:
        return 0.75, 0.15, 0.10
    else:
        return 0.80, 0.10, 0.10

# %% [markdown]
# Basic data overview, once again, not needed in method description

# %%
df_raw = pd.read_excel(XLSX_PATH, sheet_name=SHEET_NAME)
df = df_raw.copy()

#drop the cols we dont need, specified earlier
for c in DROP_COLS:
    if c in df.columns:
        df.drop(columns=c, inplace=True)

# strip column names of stray spaces
df.columns = [c.strip() for c in df.columns]

#map the blood group numerical values to their actual vals (double checking lang to be sure)
if "Blood Group" in df.columns and df["Blood Group"].dtype == object:
    df["Blood Group"] = df["Blood Group"].map(lambda x: BLOOD_GROUP_MAP.get(str(x).strip(), np.nan))

# normalize all (Y/N) columns
yn_cols = [c for c in df.columns if "(Y/N)" in c or re.search(r"\bY/?N\b", c, re.I)]
for c in yn_cols:
    df[c] = normalize_yes_no(df[c]).astype("float")  # float for imputation; cast to int later

# Coerce other object columns to numeric when possible
for c in df.columns:
    if df[c].dtype == object and c not in yn_cols:
        df[c] = pd.to_numeric(df[c].replace({"NaN": np.nan, "nan": np.nan, "": np.nan, "—": np.nan}), errors="ignore")

# Quick peek
display(df.head())
print("Rows, Cols:", df.shape)
print("Nulls: ", df.isna().sum().sum())
# Out:
# C:\Users\Jomar\AppData\Local\Temp\ipykernel_19692\593611157.py:24: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[c] = pd.to_numeric(df[c].replace({"NaN": np.nan, "nan": np.nan, "": np.nan, "—": np.nan}), errors="ignore")
#    PCOS (Y/N)  Age (yrs)  Weight (Kg)  Height(Cm)        BMI  Pulse rate(bpm)  \
# 0         0.0         28         44.6       152.0  19.300000               78
# 1         0.0         36         65.0       161.5  24.921163               74
# 2         1.0         33         68.8       165.0  25.270891               72
# 3         0.0         37         65.0       148.0  29.674945               72
# 4         0.0         25         52.0       161.0  20.060954               72
#
#    Cycle(R/I)  Cycle length(days)  No. of aborptions  I   beta-HCG(mIU/mL)  \
# 0           2                   5                  0                  1.99
# 1           2                   5                  0                 60.80
# 2           2                   5                  0                494.08
# 3           2                   5                  0                  1.99
# 4           2                   5                  0                801.45
#
#    ... PRG(ng/mL)  RBS(mg/dl)  Weight gain(Y/N)  hair growth(Y/N)  \
# 0  ...       0.57        92.0               0.0               0.0
# 1  ...       0.97        92.0               0.0               0.0
# 2  ...       0.36        84.0               0.0               0.0
# 3  ...       0.36        76.0               0.0               0.0
# 4  ...       0.38        84.0               0.0               0.0
#
#    Hair loss(Y/N)  Follicle No. (L)  Follicle No. (R)  Avg. F size (L) (mm)  \
# 0             0.0                 3                 3                  18.0
# 1             0.0                 3                 5                  15.0
# 2             1.0                13                15                  18.0
# 3             0.0                 2                 2                  15.0
# 4             1.0                 3                 4                  16.0
#
#   Avg. F size (R) (mm)  Endometrium (mm)
# 0                 18.0               8.5
# 1                 14.0               3.7
# 2                 20.0              10.0
# 3                 14.0               7.5
# 4                 14.0               7.0
#
# [5 rows x 30 columns]
# Rows, Cols: (541, 30)
# Nulls:  0

# %%
df.columns
# Out:
# Index(['PCOS (Y/N)', 'Age (yrs)', 'Weight (Kg)', 'Height(Cm)', 'BMI',
#        'Pulse rate(bpm)', 'Cycle(R/I)', 'Cycle length(days)',
#        'No. of aborptions', 'I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)',
#        'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)',
#        'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)',
#        'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Hair loss(Y/N)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %% [markdown]
# build the dataset to train on, create X, y impute and splits

# %%
assert TARGET_COL in df.columns, f"Target '{TARGET_COL}' not found; available: {list(df.columns)}"
y = df[TARGET_COL].astype(int)
X = df.drop(columns=[TARGET_COL])

# Keep numeric columns (this dataset is numeric after our mapping)
numeric_cols = [c for c in X.columns if pd.api.types.is_numeric_dtype(X[c])]
X = X[numeric_cols].copy()

# Median imputation (robust for clinical-style data)
imputer = SimpleImputer(strategy="median")
X[numeric_cols] = imputer.fit_transform(X[numeric_cols])

n_rows = len(X)
split_train, split_val, split_test = choose_splits(n_rows)

# 1) Test split
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=split_test, stratify=y, random_state=42
)

# 2) Train/Val split (from the remaining)
val_fraction_of_temp = split_val / (1.0 - split_test)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=val_fraction_of_temp, stratify=y_temp, random_state=42
)

print({
    "n_rows": n_rows,
    "split_fractions": {"train": split_train, "val": split_val, "test": split_test},
    "counts": {"train": len(X_train), "val": len(X_val), "test": len(X_test)}
})

# Class balance check
print("Class balance (train):")
print(y_train.value_counts(normalize=True).rename("pct"))
print("Class balance (val):")
print(y_val.value_counts(normalize=True).rename("pct"))
print("Class balance (test):")
print(y_test.value_counts(normalize=True).rename("pct"))

print("Class counts in train:")
print(y_train.value_counts())
# Out:
# {'n_rows': 541, 'split_fractions': {'train': 0.7, 'val': 0.15, 'test': 0.15}, 'counts': {'train': 378, 'val': 81, 'test': 82}}
# Class balance (train):
# PCOS (Y/N)
# 0    0.671958
# 1    0.328042
# Name: pct, dtype: float64
# Class balance (val):
# PCOS (Y/N)
# 0    0.679012
# 1    0.320988
# Name: pct, dtype: float64
# Class balance (test):
# PCOS (Y/N)
# 0    0.670732
# 1    0.329268
# Name: pct, dtype: float64
# Class counts in train:
# PCOS (Y/N)
# 0    254
# 1    124
# Name: count, dtype: int64

# %% [markdown]
# Some minor class imbalance

# %% [markdown]
# ##MAKE SOME FAKE DATA WITH CTGAN AND VERIFY THEIR BIOLOGICAL ACCURACY WITH PCA ANALYSIS

# %%
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import Metadata

# prepare a training seed (our train set)
train_seeds = pd.concat([X_train, y_train], axis = 1)

#define the metadata
metadata = Metadata.detect_from_dataframe(data = train_seeds, table_name = '')

#address categorical variables, force them into cat type
categorical_keywords = ["(Y/N)", "Blood Group", "Cycle(R/I)", "aborptions", "RR (breaths/min)"]
for col in train_seeds.columns:
    if any(k in col for k in categorical_keywords):
        metadata.update_column(column_name=col, sdtype='categorical')

#save metadata for reproducibility
metadata_file = Path('pcos_metadata_v1.json')
if not metadata_file.exists():
    metadata.save_to_json(str(metadata_file))
    print("Metadata blueprint saved for the first time.")
else:
    print("Metadata blueprint already exists. Skipping save to protect your audit.")

#train the synthesizer:
#1k epochs tends to be desirable for this
synthesizer = CTGANSynthesizer(metadata, epochs = 1000, cuda=torch.cuda.is_available())
synthesizer.fit(train_seeds)

#Generate nums of samples to reach 1k
n_synth_samples = 1000 - len(train_seeds)
synthetic_data = synthesizer.sample(n_synth_samples)

#separate X and y
X_synth = synthetic_data.drop(columns = [TARGET_COL])
y_synth = synthetic_data[TARGET_COL].astype(int)

#combine into a final train set
X_train_final = pd.concat([X_train, X_synth], axis = 0).reset_index(drop = True)
y_train_final = pd.concat([y_train, y_synth], axis = 0).reset_index(drop = True)

print("Augmented training composed of real:", len(X_train), "synthetic:", len(X_synth), "total:", len(X_train_final))
# Out:
# Metadata blueprint already exists. Skipping save to protect your audit.
# c:\Users\Jomar\VSCode\ML\BasicML\ML\Lib\site-packages\sdv\single_table\base.py:134: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# c:\Users\Jomar\VSCode\ML\BasicML\ML\Lib\site-packages\ctgan\synthesizers\_utils.py:16: FutureWarning:
#
# `cuda` parameter is deprecated and will be removed in a future release. Please use `enable_gpu` instead.
# Augmented training composed of real: 378 synthetic: 622 total: 1000

# %%
synthesizer.save('pcos_ctgan_model.pkl')
print("Synthesizer saved to disk.")
# Out:
# Synthesizer saved to disk.

# %%
#only run if pcos_ctgan_model.pkl already exists
#synthesizer = CTGANSynthesizer.load('pcos_ctgan_model.pkl')
#synthetic_data = synthesizer.sample(num_rows=n_synth_samples)
#print("Synthesizer loaded and samples generated.")

# %%
#verify the synthtic data is realistic

def verifyBiologicalDist(real_x, synth_x):
    scaler = RobustScaler()

    #apply scaler to both real and synth (we scale to avoid outliers messing up)
    allData = pd.concat([real_x, synth_x], axis = 0).fillna(0)
    scaledData = scaler.fit_transform(allData)

    pca = PCA(n_components=2)
    components = pca.fit_transform(scaledData)
    
    real_comp = components[:len(real_x)]
    synth_comp = components[len(real_x):]

    plt.figure(figsize=(10, 6))
    plt.scatter(synth_comp[:, 0], synth_comp[:, 1], color='red', alpha=0.2, label='Synthetic')
    plt.scatter(real_comp[:, 0], real_comp[:, 1], color='blue', alpha=0.5, label='Real')
    
    # ZOOM IN: Ignore the extreme outliers for visual verification
    plt.xlim(-5, 10) 
    plt.ylim(-5, 10)
    
    plt.title("Robust PCA: Focused Biological Space")
    plt.legend()
    plt.show()

verifyBiologicalDist(X_train, X_synth)

# %% [markdown]
# #Synthetic Data Points are incredibly close to the real ones, this is satisfactory enough

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier

#set a scale factor given the class imbalance
neg, pos = np.bincount(y_train_final)
scale = pos/neg

#stratified KFold for CV
skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=32)

# preparing the search pool
# we use X_train_final (Hybrid) as the pool, but we must index it carefully
# real data is the first len(X_train) rows; Synthetic is the rest
custom_cv_indices = []

# Generate folds from the REAL data only
for train_idx, val_idx in skf.split(X_train, y_train):
    #training indices for this fold: (Real Train indices) + (All Synthetic indices)
    #synthetic indices start at the end of the real training set
    synth_indices = np.arange(len(X_train), len(X_train_final))
    hybrid_train_idx = np.concatenate([train_idx, synth_indices])
    
    #validation indices for this fold: (Real Val indices) ONLY
    custom_cv_indices.append((hybrid_train_idx, val_idx))

# Configure and run the search
xgb_base = XGBClassifier(
    tree_method="hist",
    eval_metric="auc",
    scale_pos_weight=scale, 
    random_state=42
)

# use regularization-heavy params to fix the 'jumpy' calibration found earlier
param_dist = {
    'n_estimators': [100, 150, 200],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 4],
    'gamma': [0.5, 1.0, 1.5, 2.0],
    'reg_lambda': [1.0, 2.0, 5.0],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9]
}

random_search = RandomizedSearchCV(
    estimator=xgb_base,
    param_distributions=param_dist,
    n_iter=25,
    scoring='roc_auc',
    cv=custom_cv_indices, # Teaches on Hybrid, Judges on Real
    verbose=1,
    n_jobs=-1,
    random_state=42
)

# Fit on the combined hybrid dataset
random_search.fit(X_train_final, y_train_final)

model = random_search.best_estimator_

print(f"[OK]: Best Params: {random_search.best_params_}")
print(f"[OK]: Best CV AUC (Real Data Validation): {random_search.best_score_:.3f}")
# Out:
# Fitting 6 folds for each of 25 candidates, totalling 150 fits
# [OK]: Best Params: {'subsample': 0.7, 'reg_lambda': 1.0, 'n_estimators': 200, 'max_depth': 4, 'learning_rate': 0.05, 'gamma': 0.5, 'colsample_bytree': 0.7}
# [OK]: Best CV AUC (Real Data Validation): 0.945

# %% [markdown]
# ##Perform CrossValidation to make use of the entire dataset for validation

# %%
from sklearn.metrics import (
    average_precision_score, precision_recall_fscore_support,
    confusion_matrix, balanced_accuracy_score, matthews_corrcoef
)

def _eval_split_with_imbalance(y_true, scores, split_name):
    # Thresholded predictions at 0.5 (keep consistent with your other eval)
    pred = (scores >= 0.5).astype(int)

    # Class distribution
    n = len(y_true)
    pos = int(np.sum(y_true))
    neg = n - pos
    base_rate = pos / max(1, n)
    pred_pos = int(np.sum(pred))
    pred_pos_rate = pred_pos / max(1, n)

    # Threshold-independent metrics
    auc = roc_auc_score(y_true, scores)
    ap  = average_precision_score(y_true, scores)  # PR-AUC

    # Threshold-dependent metrics @0.5
    prec, rec, f1, _ = precision_recall_fscore_support(
        y_true, pred, average="binary", zero_division=0
    )
    tn, fp, fn, tp = confusion_matrix(y_true, pred).ravel()
    acc   = accuracy_score(y_true, pred)
    spec  = tn / (tn + fp) if (tn + fp) > 0 else np.nan  # specificity (TNR)
    bacc  = balanced_accuracy_score(y_true, pred)
    mcc   = matthews_corrcoef(y_true, pred) if len(np.unique(y_true)) == 2 else np.nan

    # Print block (keeps it readable in console/logs)
    print(f"\n[{split_name}] class distribution: "
          f"pos={pos} ({base_rate:.1%}), neg={neg} ({1-base_rate:.1%}), n={n}")
    print(f"[{split_name}] AUC={auc:.3f} | PR-AUC(AP)={ap:.3f} | "
          f"Acc@0.5={acc:.3f} | Prec@0.5={prec:.3f} | Rec@0.5={rec:.3f} | "
          f"F1@0.5={f1:.3f} | Spec@0.5={spec:.3f} | BalAcc@0.5={bacc:.3f} | MCC@0.5={mcc:.3f}")
    print(f"[{split_name}] Predicted positive rate @0.5: {pred_pos}/{n} ({pred_pos_rate:.1%})")
    print(f"[{split_name}] Confusion matrix @0.5 (rows=true, cols=pred):\n"
          f"[[TN FP]\n [FN TP]]\n{np.array([[tn, fp], [fn, tp]])}")

    return {
        "n": n, "pos": pos, "neg": neg,
        "base_rate": float(base_rate),
        "pred_pos_rate@0.5": float(pred_pos_rate),
        "AUC": float(auc), "AP": float(ap),
        "ACC@0.5": float(acc), "Precision@0.5": float(prec),
        "Recall@0.5": float(rec), "F1@0.5": float(f1),
        "Specificity@0.5": float(spec), "BalancedAcc@0.5": float(bacc),
        "MCC@0.5": float(mcc),
        "cm@0.5": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)},
    }

# %%
# We combine X_train and X_val to have a larger pool for rotation.
# X_test remains completely isolated.
X_cv_pool = pd.concat([X_train, X_val], axis=0)
y_cv_pool = pd.concat([y_train, y_val], axis=0)

#start cross validation:
cv_summaries = []

print("Starting 5-Fold Cross-Validation...")
print("Training on: Real + Synthetic | Validating on: Real Fold")

neg, pos = np.bincount(y_train_final)
scale_factor = pos / neg

for fold, (train_idx, val_idx) in enumerate(skf.split(X_cv_pool, y_cv_pool)):
    # Split real data for this fold
    X_fold_real_train = X_cv_pool.iloc[train_idx]
    y_fold_real_train = y_cv_pool.iloc[train_idx]
    X_fold_val = X_cv_pool.iloc[val_idx]
    y_fold_val = y_cv_pool.iloc[val_idx]
    
    # AUGMENTATION: Add the synthetic patients only to the training fold
    X_fold_aug = pd.concat([X_fold_real_train, X_synth], axis=0)
    y_fold_aug = pd.concat([y_fold_real_train, y_synth], axis=0)
    
    # Initialize and train fold model
    fold_model = XGBClassifier(
        n_estimators=500,
        learning_rate=0.05,
        max_depth=4,
        scale_pos_weight=scale_factor,
        tree_method="hist",
        eval_metric="auc",
        random_state=42
    )
    
    fold_model.fit(X_fold_aug, y_fold_aug)
    
    # Evaluate on the REAL validation fold
    fold_probs = fold_model.predict_proba(X_fold_val)[:, 1]
    fold_summary = _eval_split_with_imbalance(y_fold_val, fold_probs, f"Fold {fold+1}")
    cv_summaries.append(fold_summary)

# --- 3. AGGREGATE CV RESULTS ---
cv_auc_scores = [m['AUC'] for m in cv_summaries]
cv_mcc_scores = [m['MCC@0.5'] for m in cv_summaries]

print("\n" + "="*30)
print(f"CROSS-VALIDATION RESULTS (5 Folds)")
print(f"Mean AUC: {np.mean(cv_auc_scores):.3f} (+/- {np.std(cv_auc_scores):.3f})")
print(f"Mean MCC: {np.mean(cv_mcc_scores):.3f} (+/- {np.std(cv_mcc_scores):.3f})")
print("="*30)
# Out:
# Starting 5-Fold Cross-Validation...
# Training on: Real + Synthetic | Validating on: Real Fold
#
# [Fold 1] class distribution: pos=25 (32.5%), neg=52 (67.5%), n=77
# [Fold 1] AUC=0.912 | PR-AUC(AP)=0.850 | Acc@0.5=0.857 | Prec@0.5=0.792 | Rec@0.5=0.760 | F1@0.5=0.776 | Spec@0.5=0.904 | BalAcc@0.5=0.832 | MCC@0.5=0.671
# [Fold 1] Predicted positive rate @0.5: 24/77 (31.2%)
# [Fold 1] Confusion matrix @0.5 (rows=true, cols=pred):
# [[TN FP]
#  [FN TP]]
# [[47  5]
#  [ 6 19]]
#
# [Fold 2] class distribution: pos=25 (32.5%), neg=52 (67.5%), n=77
# [Fold 2] AUC=0.912 | PR-AUC(AP)=0.881 | Acc@0.5=0.870 | Prec@0.5=0.895 | Rec@0.5=0.680 | F1@0.5=0.773 | Spec@0.5=0.962 | BalAcc@0.5=0.821 | MCC@0.5=0.697
# [Fold 2] Predicted positive rate @0.5: 19/77 (24.7%)
# [Fold 2] Confusion matrix @0.5 (rows=true, cols=pred):
# [[TN FP]
#  [FN TP]]
# [[50  2]
#  [ 8 17]]
#
# [Fold 3] class distribution: pos=25 (32.5%), neg=52 (67.5%), n=77
# [Fold 3] AUC=0.933 | PR-AUC(AP)=0.886 | Acc@0.5=0.857 | Prec@0.5=0.938 | Rec@0.5=0.600 | F1@0.5=0.732 | Spec@0.5=0.981 | BalAcc@0.5=0.790 | MCC@0.5=0.670
# [Fold 3] Predicted positive rate @0.5: 16/77 (20.8%)
# [Fold 3] Confusion matrix @0.5 (rows=true, cols=pred):
# [[TN FP]
#  [FN TP]]
# [[51  1]
#  [10 15]]
#
# [Fold 4] class distribution: pos=25 (32.9%), neg=51 (67.1%), n=76
# [Fold 4] AUC=0.958 | PR-AUC(AP)=0.920 | Acc@0.5=0.895 | Prec@0.5=0.905 | Rec@0.5=0.760 | F1@0.5=0.826 | Spec@0.5=0.961 | BalAcc@0.5=0.860 | MCC@0.5=0.757
# [Fold 4] Predicted positive rate @0.5: 21/76 (27.6%)
# [Fold 4] Confusion matrix @0.5 (rows=true, cols=pred):
# [[TN FP]
#  [FN TP]]
# [[49  2]
#  [ 6 19]]
#
# [Fold 5] class distribution: pos=25 (32.9%), neg=51 (67.1%), n=76
# [Fold 5] AUC=0.940 | PR-AUC(AP)=0.898 | Acc@0.5=0.842 | Prec@0.5=0.842 | Rec@0.5=0.640 | F1@0.5=0.727 | Spec@0.5=0.941 | BalAcc@0.5=0.791 | MCC@0.5=0.631
# [Fold 5] Predicted positive rate @0.5: 19/76 (25.0%)
# [Fold 5] Confusion matrix @0.5 (rows=true, cols=pred):
# [[TN FP]
#  [FN TP]]
# [[48  3]
#  [ 9 16]]
#
# [Fold 6] class distribution: pos=25 (32.9%), neg=51 (67.1%), n=76
# [Fold 6] AUC=0.962 | PR-AUC(AP)=0.944 | Acc@0.5=0.908 | Prec@0.5=0.909 | Rec@0.5=0.800 | F1@0.5=0.851 | Spec@0.5=0.961 | BalAcc@0.5=0.880 | MCC@0.5=0.788
# [Fold 6] Predicted positive rate @0.5: 22/76 (28.9%)
# [Fold 6] Confusion matrix @0.5 (rows=true, cols=pred):
# [[TN FP]
#  [FN TP]]
# [[49  2]
#  [ 5 20]]
#
# ==============================
# CROSS-VALIDATION RESULTS (5 Folds)
# Mean AUC: 0.936 (+/- 0.020)
# Mean MCC: 0.702 (+/- 0.054)
# ==============================

# %%
#final model test
val_scores = model.predict_proba(X_val)[:, 1]
test_scores = model.predict_proba(X_test)[:, 1]

# Evaluate both splits with the extra metrics
val_summary  = _eval_split_with_imbalance(y_val,  val_scores,  "Validation")
test_summary = _eval_split_with_imbalance(y_test, test_scores, "Test")
# Out:
# [Validation] class distribution: pos=26 (32.1%), neg=55 (67.9%), n=81
# [Validation] AUC=0.960 | PR-AUC(AP)=0.949 | Acc@0.5=0.951 | Prec@0.5=1.000 | Rec@0.5=0.846 | F1@0.5=0.917 | Spec@0.5=1.000 | BalAcc@0.5=0.923 | MCC@0.5=0.888
# [Validation] Predicted positive rate @0.5: 22/81 (27.2%)
# [Validation] Confusion matrix @0.5 (rows=true, cols=pred):
# [[TN FP]
#  [FN TP]]
# [[55  0]
#  [ 4 22]]
#
# [Test] class distribution: pos=27 (32.9%), neg=55 (67.1%), n=82
# [Test] AUC=0.846 | PR-AUC(AP)=0.847 | Acc@0.5=0.890 | Prec@0.5=1.000 | Rec@0.5=0.667 | F1@0.5=0.800 | Spec@0.5=1.000 | BalAcc@0.5=0.833 | MCC@0.5=0.757
# [Test] Predicted positive rate @0.5: 18/82 (22.0%)
# [Test] Confusion matrix @0.5 (rows=true, cols=pred):
# [[TN FP]
#  [FN TP]]
# [[55  0]
#  [ 9 18]]

# %%
from sklearn.metrics import f1_score, precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_val, val_scores)
f1_scores = 2 * (precision * recall) / (precision + recall + 1e-10)
best_threshold = thresholds[np.argmax(f1_scores)]

print(f" Calibrated Optimal Threshold: {best_threshold:.3f}")

# Instead of using model.predict() [which uses 0.5], we manually threshold
custom_test_preds = (test_scores >= best_threshold).astype(int)

# We need a slightly modified version of your eval function 
# that accepts these custom 'preds' rather than calculating them from 0.5
def eval_with_custom_threshold(y_true, scores, custom_preds, split_name):
    # This is essentially your _eval_split_with_imbalance code 
    # but using 'custom_preds' for the confusion matrix and F1/MCC
    auc = roc_auc_score(y_true, scores)
    mcc = matthews_corrcoef(y_true, custom_preds)
    f1 = f1_score(y_true, custom_preds) # Ensure f1_score is imported
    
    print(f"[{split_name}] Adjusted Threshold Metrics:")
    print(f"Threshold: {best_threshold:.3f} | AUC: {auc:.3f} | MCC: {mcc:.3f} | F1: {f1:.3f}")
    
    return mcc

final_mcc = eval_with_custom_threshold(y_test, test_scores, custom_test_preds, "Final Test")
# Out:
#  Calibrated Optimal Threshold: 0.506
# [Final Test] Adjusted Threshold Metrics:
# Threshold: 0.506 | AUC: 0.846 | MCC: 0.757 | F1: 0.800

# %%
# ---- Compact paper-friendly summary footer ----
def _pct(x): return f"{100*x:.1f}%"
imbalance_flag = "(imbalance noted)" if abs(val_summary["base_rate"] - 0.5) > 0.10 else "(near-balanced)"

print("\n=== Summary (tabular) ===")
print(f"Base rate (positives):  Validation {_pct(val_summary['base_rate'])} {imbalance_flag}; "
      f"Test {_pct(test_summary['base_rate'])}")
print(f"ROC-AUC:  val {val_summary['AUC']:.3f} | test {test_summary['AUC']:.3f}  ·  "
      f"PR-AUC(AP): val {val_summary['AP']:.3f} | test {test_summary['AP']:.3f}")
print(f"@0.5 — Validation:  Acc {val_summary['ACC@0.5']:.3f} | "
      f"Prec {val_summary['Precision@0.5']:.3f} | Rec {val_summary['Recall@0.5']:.3f} | "
      f"F1 {val_summary['F1@0.5']:.3f} | Spec {val_summary['Specificity@0.5']:.3f} | "
      f"BalAcc {val_summary['BalancedAcc@0.5']:.3f} | MCC {val_summary['MCC@0.5']:.3f}")
print(f"@0.5 — Test:        Acc {test_summary['ACC@0.5']:.3f} | "
      f"Prec {test_summary['Precision@0.5']:.3f} | Rec {test_summary['Recall@0.5']:.3f} | "
      f"F1 {test_summary['F1@0.5']:.3f} | Spec {test_summary['Specificity@0.5']:.3f} | "
      f"BalAcc {test_summary['BalancedAcc@0.5']:.3f} | MCC {test_summary['MCC@0.5']:.3f}")
# Out:
# === Summary (tabular) ===
# Base rate (positives):  Validation 32.1% (imbalance noted); Test 32.9%
# ROC-AUC:  val 0.960 | test 0.846  ·  PR-AUC(AP): val 0.949 | test 0.847
# @0.5 — Validation:  Acc 0.951 | Prec 1.000 | Rec 0.846 | F1 0.917 | Spec 1.000 | BalAcc 0.923 | MCC 0.888
# @0.5 — Test:        Acc 0.890 | Prec 1.000 | Rec 0.667 | F1 0.800 | Spec 1.000 | BalAcc 0.833 | MCC 0.757

# %%
import pandas as pd

# ---- Make tabular summary for paper/report ----
summary_df = pd.DataFrame([
    {
        "Split": "Validation",
        "Positives": f"{val_summary['pos']} / {val_summary['n']} ({100*val_summary['base_rate']:.1f}%)",
        "AUC": f"{val_summary['AUC']:.3f}",
        "PR-AUC": f"{val_summary['AP']:.3f}",
        "Accuracy": f"{val_summary['ACC@0.5']:.3f}",
        "Precision": f"{val_summary['Precision@0.5']:.3f}",
        "Recall": f"{val_summary['Recall@0.5']:.3f}",
        "F1-Score": f"{val_summary['F1@0.5']:.3f}",
        "Specificity": f"{val_summary['Specificity@0.5']:.3f}",
        "BalAcc": f"{val_summary['BalancedAcc@0.5']:.3f}",
        "MCC": f"{val_summary['MCC@0.5']:.3f}"
    },
    {
        "Split": "Test",
        "Positives": f"{test_summary['pos']} / {test_summary['n']} ({100*test_summary['base_rate']:.1f}%)",
        "AUC": f"{test_summary['AUC']:.3f}",
        "PR-AUC": f"{test_summary['AP']:.3f}",
        "Accuracy": f"{test_summary['ACC@0.5']:.3f}",
        "Precision": f"{test_summary['Precision@0.5']:.3f}",
        "Recall": f"{test_summary['Recall@0.5']:.3f}",
        "F1-Score": f"{test_summary['F1@0.5']:.3f}",
        "Specificity": f"{test_summary['Specificity@0.5']:.3f}",
        "BalAcc": f"{test_summary['BalancedAcc@0.5']:.3f}",
        "MCC": f"{test_summary['MCC@0.5']:.3f}"
    }
])

# Display neatly in Jupyter / console
print("\n=== Model Evaluation Summary (Tabular Classifier) ===")
display(summary_df.style.set_table_styles(
    [{"selector": "th", "props": [("text-align", "center"), ("font-weight", "bold")]}]
).set_properties(**{"text-align": "center"}))
# Out:
# === Model Evaluation Summary (Tabular Classifier) ===
# <style type="text/css">
# #T_55f25 th {
#   text-align: center;
#   font-weight: bold;
# }
# #T_55f25_row0_col0, #T_55f25_row0_col1, #T_55f25_row0_col2, #T_55f25_row0_col3, #T_55f25_row0_col4, #T_55f25_row0_col5, #T_55f25_row0_col6, #T_55f25_row0_col7, #T_55f25_row0_col8, #T_55f25_row0_col9, #T_55f25_row0_col10, #T_55f25_row1_col0, #T_55f25_row1_col1, #T_55f25_row1_col2, #T_55f25_row1_col3, #T_55f25_row1_col4, #T_55f25_row1_col5, #T_55f25_row1_col6, #T_55f25_row1_col7, #T_55f25_row1_col8, #T_55f25_row1_col9, #T_55f25_row1_col10 {
#   text-align: center;
# }
# </style>
# <table id="T_55f25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55f25_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_55f25_level0_col1" class="col_heading level0 col1" >Positives</th>
#       <th id="T_55f25_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_55f25_level0_col3" class="col_heading level0 col3" >PR-AUC</th>
#       <th id="T_55f25_level0_col4" class="col_heading level0 col4" >Accuracy</th>
#       <th id="T_55f25_level0_col5" class="col_heading level0 col5" >Precision</th>
#       <th id="T_55f25_level0_col6" class="col_heading level0 col6" >Recall</th>
#       <th id="T_55f25_level0_col7" class="col_heading level0 col7" >F1-Score</th>
#       <th id="T_55f25_level0_col8" class="col_heading level0 col8" >Specificity</th>
#       <th id="T_55f25_level0_col9" class="col_heading level0 col9" >BalAcc</th>
#       <th id="T_55f25_level0_col10" class="col_heading level0 col10" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55f25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55f25_row0_col0" class="data row0 col0" >Validation</td>
#       <td id="T_55f25_row0_col1" class="data row0 col1" >26 / 81 (32.1%)</td>
#       <td id="T_55f25_row0_col2" class="data row0 col2" >0.960</td>
#       <td id="T_55f25_row0_col3" class="data row0 col3" >0.949</td>
#       <td id="T_55f25_row0_col4" class="data row0 col4" >0.951</td>
#       <td id="T_55f25_row0_col5" class="data row0 col5" >1.000</td>
#       <td id="T_55f25_row0_col6" class="data row0 col6" >0.846</td>
#       <td id="T_55f25_row0_col7" class="data row0 col7" >0.917</td>
#       <td id="T_55f25_row0_col8" class="data row0 col8" >1.000</td>
#       <td id="T_55f25_row0_col9" class="data row0 col9" >0.923</td>
#       <td id="T_55f25_row0_col10" class="data row0 col10" >0.888</td>
#     </tr>
#     <tr>
#       <th id="T_55f25_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55f25_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_55f25_row1_col1" class="data row1 col1" >27 / 82 (32.9%)</td>
#       <td id="T_55f25_row1_col2" class="data row1 col2" >0.846</td>
#       <td id="T_55f25_row1_col3" class="data row1 col3" >0.847</td>
#       <td id="T_55f25_row1_col4" class="data row1 col4" >0.890</td>
#       <td id="T_55f25_row1_col5" class="data row1 col5" >1.000</td>
#       <td id="T_55f25_row1_col6" class="data row1 col6" >0.667</td>
#       <td id="T_55f25_row1_col7" class="data row1 col7" >0.800</td>
#       <td id="T_55f25_row1_col8" class="data row1 col8" >1.000</td>
#       <td id="T_55f25_row1_col9" class="data row1 col9" >0.833</td>
#       <td id="T_55f25_row1_col10" class="data row1 col10" >0.757</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi = (
    pd.Series(model.feature_importances_, index=X_train.columns)
    .sort_values(ascending=False)
    .to_frame("importance")
)
display(fi)
# Out:
#                       importance
# hair growth(Y/N)        0.112811
# Weight gain(Y/N)        0.059857
# Follicle No. (L)        0.055178
# Follicle No. (R)        0.048714
# Cycle(R/I)              0.047982
# Cycle length(days)      0.041897
# FSH(mIU/mL)             0.040505
# I   beta-HCG(mIU/mL)    0.038297
# FSH/LH                  0.034806
# Waist:Hip Ratio         0.034624
# Weight (Kg)             0.034495
# Height(Cm)              0.030673
# No. of aborptions       0.030472
# Avg. F size (R) (mm)    0.030385
# PRG(ng/mL)              0.030188
# LH(mIU/mL)              0.029708
# Age (yrs)               0.029635
# BMI                     0.029137
# TSH (mIU/L)             0.028656
# RBS(mg/dl)              0.028637
# Pulse rate(bpm)         0.028305
# Avg. F size (L) (mm)    0.028103
# Hip(inch)               0.027757
# PRL(ng/mL)              0.027664
# Endometrium (mm)        0.026429
# Waist(inch)             0.025347
# Hair loss(Y/N)          0.019738

# %% [markdown]
# ##FINAL CHECK FOR XGBOOST MODEL VIABILITY ON CTGAN GENERATED DATA

# %%
import shap
from sklearn.calibration import calibration_curve
from sklearn.ensemble import RandomForestClassifier

# we use a XGB on purely real data to see what the "Natural" top features are
real_baseline = XGBClassifier(n_estimators=100, max_depth=3, random_state=42)
real_baseline.fit(X_train, y_train)

#check for feature rank consistency
hybrid_fi = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
real_fi = pd.Series(real_baseline.feature_importances_, index=X_train.columns).sort_values(ascending=False)

#SHAP ANALYSIS to see how features contribute to a prediction
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

# --- VISUALIZATION ---
plt.figure(figsize=(18, 5))

# Plot A: Feature Rank Correlation (Are the "Tells" consistent?)
plt.subplot(1, 3, 1)
top_10_hybrid = hybrid_fi.head(10).index
top_10_real = real_fi.head(10).index
overlap = len(set(top_10_hybrid).intersection(set(top_10_real)))
plt.bar(["Top 10 Overlap"], [overlap], color='teal')
plt.ylim(0, 10)
plt.title(f"Rank Consistency: {overlap}/10\n(High is Better)")

# Plot B: Probability Calibration (Is '70% Risk' real?)
plt.subplot(1, 3, 2)
prob_true, prob_pred = calibration_curve(y_test, test_scores, n_bins=5)
plt.plot(prob_pred, prob_true, marker='o', label='XGBoost')
plt.plot([0, 1], [0, 1], linestyle='--', label='Perfectly Calibrated')
plt.xlabel("Predicted Risk Level")
plt.ylabel("Actual PCOS Frequency")
plt.title("Risk Calibration Curve")
plt.legend()

# Plot C: SHAP Summary (Directional Sanity Check)
plt.subplot(1, 3, 3)
# Note: We use plt.sca to force SHAP into the subplot
shap.summary_plot(shap_values, X_test, plot_type="bar", show=False)
plt.title("Clinical Logic (Feature Impact)")

plt.tight_layout()
plt.show()

# --- CLINICAL LOGIC AUDIT ---
print("\n=== CLINICAL LOGIC AUDIT ===")

# Check 1: Feature Stability
critical_match = all(feat in real_fi.head(7).index for feat in hybrid_fi.head(3).index)
if critical_match:
    print("[OK]: Top 3 hybrid features are verified by real-world baseline.")
else:
    print("[ERROR]: Top hybrid features differ significantly from real baseline. Audit CTGAN fidelity.")

# Check 2: Over-confidence vs Precision
max_prob = test_scores.max()
precision_05 = test_summary.get('Precision@0.5', 0)
if max_prob > 0.95 and precision_05 < 0.75:
    print(f"[ERROR]: Over-confidence detected. Max Prob {max_prob:.2f} but Precision {precision_05:.2f}.")
else:
    print("[OK]: Model confidence is aligned with real-world precision.")

# Check 3: Calibration Deviation
calibration_error = np.mean(np.abs(prob_true - prob_pred))
if calibration_error > 0.15:
    print(f"[ERROR]: High Calibration Bias ({calibration_error:.3f}). Risk levels may be misleading.")
else:
    print(f"[OK]: Probability calibration is within acceptable medical margin ({calibration_error:.3f}).")
# Out:
# === CLINICAL LOGIC AUDIT ===
# [OK]: Top 3 hybrid features are verified by real-world baseline.
# [OK]: Model confidence is aligned with real-world precision.
# [OK]: Probability calibration is within acceptable medical margin (0.130).

# %% [markdown]
# # Export model to ONNX format
# Here we'll export the trained XGBoost model to ONNX format for deployment and reuse.

# %%
# --- Normalize XGBoost feature names to f0, f1, ... for onnxmltools ---
booster = model.get_booster()

# Preserve ordering, just rename to f0..f{n-1}
n_feats = len(booster.feature_names or [])
booster.feature_names = [f"f{i}" for i in range(n_feats)]

# Some XGBoost versions also store feature_types; make them all numeric floats
try:
    booster.feature_types = ['float'] * n_feats
except Exception:
    pass  # not present in all versions

# Now do the conversion
from onnxmltools.convert import convert_xgboost
from onnxmltools.convert.common.data_types import FloatTensorType

input_shape = [None, model.n_features_in_]
initial_type = [('float_input', FloatTensorType(input_shape))]

onx = convert_xgboost(model, initial_types=initial_type, target_opset=13)

# %%
# --- Export XGBoost to ONNX with BOTH label + probability and test rigorously ---

from pathlib import Path
import numpy as np
import onnx, onnxruntime as rt
from onnxmltools.convert import convert_xgboost
from onnxmltools.convert.common.data_types import FloatTensorType

# 1) Prepare export
ONNX_DIR = Path("onnx_models"); ONNX_DIR.mkdir(parents=True, exist_ok=True)
onnx_path = ONNX_DIR / "pcos_tabular_model.onnx"

# 2) (Optional) Temporarily rename booster feature names to f0.. to keep onnxmltools happy
booster = model.get_booster()
orig_names = booster.feature_names[:] if booster.feature_names is not None else None
if orig_names is not None:
    booster.feature_names = [f"f{i}" for i in range(len(orig_names))]
    try:
        booster.feature_types = ['float'] * len(orig_names)  # not always present
    except Exception:
        pass

# 3) Convert with probabilities ON (disable ZipMap so we get a tensor instead of a dict)
initial_type = [('float_input', FloatTensorType([None, model.n_features_in_]))]
try:
    onx = convert_xgboost(
        model,
        initial_types=initial_type,
        target_opset=13,
        options={'zipmap': False}  # <- ask for tensor probs
    )
except TypeError:
    # Some versions don't accept 'options' here; fall back without it.
    onx = convert_xgboost(model, initial_types=initial_type, target_opset=13)

# Restore original booster names so sklearn predict_proba with pandas keeps working
if orig_names is not None:
    booster.feature_names = orig_names

# 4) Save + check model
with open(onnx_path, "wb") as f:
    f.write(onx.SerializeToString())

onnx.checker.check_model(onx)
print(f"ONNX export OK → {onnx_path}")

# 5) Inspect outputs so we know which index is label vs prob
sess = rt.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
print("\nONNX outputs:")
for i, o in enumerate(sess.get_outputs()):
    print(f"  [{i}] name={o.name}, shape={o.shape}, type={o.type}")

# 6) Helper to run ONNX and return (label, prob) consistently
def onnx_predict_label_prob(session, X_np: np.ndarray):
    outs = session.run(None, {session.get_inputs()[0].name: X_np.astype(np.float32)})
    # Heuristics:
    # - When options={'zipmap': False} worked: outs[0]=label, outs[1]=probs (2-class tensor)
    # - Without options: could be [label] only, or [label, probability-map/dict]
    if len(outs) == 2:
        label = outs[0].ravel()
        probs = outs[1]
        # If probs is (N,2), take positive class (index 1)
        if probs.ndim == 2 and probs.shape[1] == 2:
            p_pos = probs[:, 1]
        else:
            # Some converters emit a single-column prob of the positive class
            p_pos = probs.ravel()
        return label, p_pos
    elif len(outs) == 1:
        # Single output: it’s almost always label (0/1). Return label and None for prob.
        return outs[0].ravel(), None
    else:
        raise RuntimeError(f"Unexpected number of ONNX outputs: {len(outs)}")

# 7) Sanity checks (single sample + small batch)
# Use NumPy (not pandas) to avoid XGBoost name validation conflicts
X_np_test = X_test.to_numpy(dtype=np.float32)

# Single sample check
lbl_onx_1, prob_onx_1 = onnx_predict_label_prob(sess, X_np_test[:1])
proba_xgb_1 = model.predict_proba(X_np_test[:1])[:, 1]
pred_xgb_1 = (proba_xgb_1 >= 0.5).astype(np.int64)

print("\n[Single sample check]")
print(f"XGB proba: {proba_xgb_1[0]:.6f} | XGB label: {pred_xgb_1[0]}")
if prob_onx_1 is not None:
    print(f"ONNX proba: {prob_onx_1[0]:.6f}")
else:
    print("ONNX proba: <not provided by this export>")
print(f"ONNX label: {int(lbl_onx_1[0])}")

# Batch check (first 32 rows or fewer)
n = min(32, len(X_np_test))
lbl_onx_b, prob_onx_b = onnx_predict_label_prob(sess, X_np_test[:n])
proba_xgb_b = model.predict_proba(X_np_test[:n])[:, 1]
pred_xgb_b = (proba_xgb_b >= 0.5).astype(np.int64)

print(f"\n[Batch check: n={n}]")
# Compare labels
label_match = (pred_xgb_b == lbl_onx_b.astype(np.int64)).mean()
print(f"Label agreement (threshold 0.5): {label_match*100:.2f}%")

# Compare probabilities if available
if prob_onx_b is not None:
    abs_diffs = np.abs(prob_onx_b - proba_xgb_b)
    print(f"Prob mean abs diff: {abs_diffs.mean():.6e}")
    print(f"Prob max  abs diff: {abs_diffs.max():.6e}")
else:
    print("ONNX probabilities not present; if you want them, re-export with options={'zipmap': False}.")
# Out:
# ONNX export OK → onnx_models\pcos_tabular_model.onnx
#
# ONNX outputs:
#   [0] name=label, shape=[None], type=tensor(int64)
#   [1] name=probabilities, shape=[None, 2], type=tensor(float)
#
# [Single sample check]
# XGB proba: 0.240344 | XGB label: 0
# ONNX proba: 0.240344
# ONNX label: 0
#
# [Batch check: n=32]
# Label agreement (threshold 0.5): 100.00%
# Prob mean abs diff: 5.622860e-08
# Prob max  abs diff: 1.341105e-07
